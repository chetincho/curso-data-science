# %% [markdown]
# Datos generados con ChatGPT:: Respuesta
#
# Hasta mi última actualización en enero de 2022, las siguientes son algunas de las películas que han ganado múltiples premios Oscar a lo largo de los años:
# "Ben-Hur" (1959): Ganó 11 premios Oscar, incluyendo Mejor Película y Mejor Director.
# "Titanic" (1997): Ganó 11 premios Oscar, incluyendo Mejor Película y Mejor Director (James Cameron).
# "El señor de los anillos: El retorno del rey" (2003): Ganó 11 premios Oscar, incluyendo Mejor Película y Mejor Director (Peter Jackson).
# "La La Land" (2016): Ganó 6 premios Oscar, aunque inicialmente fue anunciada incorrectamente como la ganadora de Mejor Película en lugar de "Moonlight".
# "Cadena perpetua" (1994): Ganó 7 premios Oscar, aunque no ganó en la categoría principal de Mejor Película.
#
# Es importante tener en cuenta que esta información puede cambiar con el tiempo debido a nuevas ceremonias de premios y el lanzamiento de nuevas películas. Te recomendaría verificar las fuentes más recientes para obtener la información más actualizada sobre las películas con más premios Oscar.

# %%
from matplotlib import pyplot as plt

# %%
peliculas = [
            "Ben-Hur (1959)", 
            "Titanic (1997)", 
            "El señor de los anillos: El retorno del rey (2003)",
            "La La Land (2016)",
            "Cadena perpetua (1994)"]

cant_premios_oscar = [11, 11, 11, 6, 7]

# %%
plt.bar(peliculas, cant_premios_oscar)
# Customización del gráfico
    # Título del gráfico
plt.title("Cantidad de Premios Oscar por Película")
    # Título para el eje y
plt.ylabel("Cant. Premios Oscar")
    # Título para el eje x
plt.xlabel("Películas")
    # Ajusto las etiquetas del eje x
plt.xticks(rotation=45, ha="right", fontsize=8)
    # Ajusto las etiquetas del eje y
plt.yticks(fontsize=8)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 2.0, '2'),
#   Text(0, 4.0, '4'),
#   Text(0, 6.0, '6'),
#   Text(0, 8.0, '8'),
#   Text(0, 10.0, '10'),
#   Text(0, 12.0, '12')])
