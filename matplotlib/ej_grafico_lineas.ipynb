# %% [markdown]
# Datos generados con ChatGPT:: Respuesta
#
# Hasta mi última actualización en enero de 2022, no tengo acceso a datos en tiempo real, y mi capacidad para proporcionar información actualizada está limitada a mi fecha de conocimiento. A continuación, te proporciono la información sobre la población de los Estados Unidos en los últimos censos hasta 2020:
#
# |   Año     |    Población (millones)|
# |-----------|------------------------|
# |   1790    |           4.0            |
# |   1800    |           5.3            |
# |   1810    |           7.2            |
# |   1820    |           9.6            |
# |   1830    |          12.9           |
# |   1840    |          17.1           |
# |   1850    |          23.2           |
# |   1860    |          31.4           |
# |   1870    |          38.6           |
# |   1880    |          50.2           |
# |   1890    |          62.9           |
# |   1900    |          76.2           |
# |   1910    |          92.2           |
# |   1920    |         106.0           |
# |   1930    |         123.2           |
# |   1940    |         132.2           |
# |   1950    |         151.3           |
# |   1960    |         179.3           |
# |   1970    |         203.3           |
# |   1980    |         226.5           |
# |   1990    |         248.7           |
# |   2000    |         281.4           |
# |   2010    |         308.7           |
# |   2020    |         331.0           |
#
# Estos números son aproximados y proporcionan una visión general de la evolución de la población en los Estados Unidos a lo largo de los censos históricos. Ten en cuenta que las cifras exactas pueden variar y se recomienda consultar fuentes oficiales para obtener datos más precisos y actualizados.

# %%
from matplotlib import pyplot as plt

# %%
# Lista de años de cada censo
anios_censo = [1790, 1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880,
              1890, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980,
              1990, 2000, 2010, 2020]

# Lista de cantidad de habitantes censados en millones
poblacion_censo = [4.0, 5.3, 7.2, 9.6, 12.9, 17.1, 23.2, 31.4, 38.6, 50.2,
                   62.9, 76.2, 92.2, 106.0, 123.2, 132.2, 151.3, 179.3, 203.3, 226.5,
                   248.7, 281.4, 308.7, 331.0]

# %%
plt.plot(anios_censo, poblacion_censo, color="green", marker="o", linestyle="solid")

# Customización del gráfico
    # Título del gráfico
plt.title("Evolucion de la Población de EEUU desde 1970")
    # Personalización
plt.xlabel("Censos")
plt.ylabel("Habitantes censados en millones")
# Out:
# Text(0, 0.5, 'Habitantes censados en millones')
